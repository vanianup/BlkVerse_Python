# %% [markdown]
# 03 Sept - Check if the year entered by the user is a leap year

# %%
Yr=input('Enter Year: ')
if int(Yr) % 4 == 0:
  print("Year",Yr,"is a leap year")
else:
  print("Year",Yr,"is not a leap year")

# %% [markdown]
# 03 Sept - Convert centimeter to Feet and inches

# %%
centmt=int(input("Enter the length in centimeter: "))
conv = centmt/30.48
ft=int(conv)
inch= round((conv-ft) * 12 , 2)
print("length in feet and inches is :",ft,"feet,",inch,"inches")
